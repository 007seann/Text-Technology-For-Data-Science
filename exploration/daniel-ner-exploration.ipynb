# %%
import spacy
from lxml import etree

# %%
NER = spacy.load('en_core_web_sm')

# %%
for word in NER("19 JUNE 1999").ents:
    print(word.text, word.label_)
# Out:
# 19 JUNE 1999 DATE

# %%
date_dict = {"MAY": "05", "JUN": "06"}

# %%
NER("1996 05 22").ents[0].label_
# Out:
# 'DATE'

# %%
with open("trec.5000.xml", 'r') as f:
    tree = etree.parse(f)
    date_set = set()
    for x in tree.iter():
        if x.tag.lower() == "headline":
            preprocessed_text = x.text.replace("FT", "").strip().replace("\n", " ")
            split_preprocessed_text = [sentence.strip() for sentence in preprocessed_text.split("/")]
            date = split_preprocessed_text[0]
            split_date = date.split()
            day = split_date[0]

            month = split_date[1]
            if month in date_dict:
                month = date_dict[month]

            year = split_date[2]
            if int(year) > 24:
                year = "19" + year
            else:
                year = "20" + year

            headline = split_preprocessed_text[1]
            full_date = "{}-{}-{}".format(year, month, day)
            date_ner = NER(full_date).ents[0].label_
            headline_ner = NER(headline).ents
            print("Date: ", full_date, date_ner)
            print("Raw headline: ", headline)
            for word in headline_ner:
                print("NER Headline: ", word.text, word.label_)
# Out:
# Date:  1992-06-02 DATE
# Raw headline:  World Stock Markets (America): Growing optimism lifts Dow Jones to record high
# NER Headline:  World Stock Markets (America): Growing ORG
# NER Headline:  Dow Jones ORG
# Date:  1992-06-02 DATE
# Raw headline:  Foreign Exchanges: Dollar rises on US indicators
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  Money Markets: Short rates softer
# Date:  1992-06-02 DATE
# Raw headline:  World Commodities Prices: Market Report
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: Fresh 'mad cow' study urged
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: CIS metal output lower than estimated, says report
# NER Headline:  CIS ORG
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: Ekofisk oilfield back to full production
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: US silver mine closes because of low prices
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: Mr Koskov's copper-bottomed business plan - One of Russia's small but growing band of entrepreneurs talks to Kenneth Gooding
# NER Headline:  Koskov PERSON
# NER Headline:  Russia GPE
# NER Headline:  Kenneth Gooding PERSON
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: Mexico embraces the international financial markets - The share offerings and foreign listing which have made an impact on the country's business methods
# NER Headline:  International Capital Markets ORG
# NER Headline:  Mexico GPE
# Date:  1992-06-02 DATE
# Raw headline:  Government Bonds: Strong purchasing data trigger selling of Treasuries
# NER Headline:  Treasuries GPE
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: Protests likely over CBS plan for new charges
# NER Headline:  International Capital Markets ORG
# NER Headline:  CBS ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: S&P cuts debt rating on four US airlines
# NER Headline:  International Capital Markets ORG
# NER Headline:  S&P ORG
# NER Headline:  four CARDINAL
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: MCA to spend extra Dollars 200m on theme parks
# NER Headline:  International Company News ORG
# NER Headline:  MCA ORG
# NER Headline:  Dollars 200 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Taxing times for multinationals in Argentina - In 1983, companies such as Shell, Firestone and BAT Industries entered the South American's government-sanctioned secondary market in tax credits. But within five years, their experience became a tale of fraud, corruption and taxation  - Argentine style
# NER Headline:  International Company News ORG
# NER Headline:  Argentina GPE
# NER Headline:  1983 DATE
# NER Headline:  Shell ORG
# NER Headline:  Firestone ORG
# NER Headline:  BAT Industries ORG
# NER Headline:  South American NORP
# NER Headline:  five years DATE
# NER Headline:  Argentine NORP
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Citibank Canada chief to leave
# NER Headline:  International Company News ORG
# NER Headline:  Citibank Canada ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Warner fails to commit to Sony Mini Disc
# NER Headline:  International Company News ORG
# NER Headline:  Warner ORG
# NER Headline:  Sony ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Zider to apple lager - country smocks to urban image
# NER Headline:  UK Company News ORG
# Date:  1992-06-02 DATE
# Raw headline:  Dunhill to buy Karl Lagerfeld fashion business
# NER Headline:  Karl Lagerfeld PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Big Six hit by recession and competition: Accountancy firms cut staff - Audit work suffers
# Date:  1992-06-02 DATE
# Raw headline:  Serbs defy UN to hit Sarajevo: Energy supplies may be rationed as international sanctions begin to bite
# NER Headline:  Serbs NORP
# NER Headline:  UN ORG
# NER Headline:  Sarajevo: Energy ORG
# Date:  1992-06-02 DATE
# Raw headline:  Letter: The myth surrounding vocational training
# Date:  1992-06-02 DATE
# Raw headline:  Letter: Rates burden having destructive effect on empty properties
# Date:  1992-06-02 DATE
# Raw headline:  Key is not to produce less - but differently
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Comprehensive
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Inflation
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Right choice
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Career paths
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Hard graft
# Date:  1992-06-02 DATE
# Raw headline:  Observer: Step in the right direction
# Date:  1992-06-02 DATE
# Raw headline:  The charge of the pension brigade: As UK regulations come under scrutiny
# NER Headline:  UK GPE
# Date:  1992-06-02 DATE
# Raw headline:  Leading Article: The next step in housing
# Date:  1992-06-02 DATE
# Raw headline:  Leading Article: The isolation of Serbia
# NER Headline:  Serbia GPE
# Date:  1992-06-02 DATE
# Raw headline:  Arts: A surrealist cast of symbols - Sculpture
# Date:  1992-06-02 DATE
# Raw headline:  People: Hanson to groom its media image
# Date:  1992-06-02 DATE
# Raw headline:  People: GA looks for change
# Date:  1992-06-02 DATE
# Raw headline:  Technology: Here's one for the road
# Date:  1992-06-02 DATE
# Raw headline:  Pledge by Major on Brussels powers
# NER Headline:  Brussels GPE
# Date:  1992-06-02 DATE
# Raw headline:  Solicitors face levy to meet sharp rise in fraud claims
# Date:  1992-06-02 DATE
# Raw headline:  BR to introduce station nurseries
# NER Headline:  BR PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Pit deadline
# Date:  1992-06-02 DATE
# Raw headline:  London crime rises
# NER Headline:  London GPE
# Date:  1992-06-02 DATE
# Raw headline:  Engineers warn on skills shortage
# Date:  1992-06-02 DATE
# Raw headline:  Election boost for unit trusts
# Date:  1992-06-02 DATE
# Raw headline:  Customers 'ignorant' of water penalties
# Date:  1992-06-02 DATE
# Raw headline:  Business school director resigns
# Date:  1992-06-02 DATE
# Raw headline:  Trouble spot
# Date:  1992-06-02 DATE
# Raw headline:  Lamont defies EC demands on VAT
# NER Headline:  Lamont PERSON
# NER Headline:  EC ORG
# NER Headline:  VAT ORG
# Date:  1992-06-02 DATE
# Raw headline:  Routes to being considered for an honour
# Date:  1992-06-02 DATE
# Raw headline:  PM sustains orders of vanished empire
# Date:  1992-06-02 DATE
# Raw headline:  Police case
# Date:  1992-06-02 DATE
# Raw headline:  Decision on Ulster talks
# NER Headline:  Ulster PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Discussion on aid for Names
# NER Headline:  Names PERSON
# Date:  1992-06-02 DATE
# Raw headline:  BSkyB and BBC confirm FA deal
# NER Headline:  BBC ORG
# Date:  1992-06-02 DATE
# Raw headline:  Big double-glazing company fails: MP demands rapid inquiry by official receiver 'to ensure there has been no malpractice'
# Date:  1992-06-02 DATE
# Raw headline:  Warning by Bank on foreign mergers
# NER Headline:  Bank ORG
# Date:  1992-06-02 DATE
# Raw headline:  Union chief warns on Labour party funding
# NER Headline:  Labour ORG
# Date:  1992-06-02 DATE
# Raw headline:  Concern at 'fragility' of training policy
# Date:  1992-06-02 DATE
# Raw headline:  Bright lights
# Date:  1992-06-02 DATE
# Raw headline:  BT job loss move opposed
# NER Headline:  BT GPE
# Date:  1992-06-02 DATE
# Raw headline:  Lenders will defend record
# Date:  1992-06-02 DATE
# Raw headline:  Smaller pay rises 'vital' says Heseltine
# NER Headline:  Heseltine PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Gas-fired power stations criticised
# Date:  1992-06-02 DATE
# Raw headline:  Broker accused of making false statement
# Date:  1992-06-02 DATE
# Raw headline:  Chambers offered single roof: Moves to merge two business organisations
# NER Headline:  two CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  World Trade News: French share in railway order for Bratislava
# NER Headline:  World Trade News ORG
# NER Headline:  French NORP
# NER Headline:  Bratislava PERSON
# Date:  1992-06-02 DATE
# Raw headline:  World Trade News: Eurofer concerned at steel from E Europe
# NER Headline:  World Trade News ORG
# NER Headline:  Eurofer PERSON
# NER Headline:  E Europe LOC
# Date:  1992-06-02 DATE
# Raw headline:  World Trade News: Western donors urged to ease aid conditions
# NER Headline:  World Trade News ORG
# Date:  1992-06-02 DATE
# Raw headline:  World Trade News: Cartels prove a hard nut for Japan to crack - Anti-monopoly body meets its match in construction sector
# NER Headline:  World Trade News ORG
# NER Headline:  Cartels ORG
# NER Headline:  Japan GPE
# Date:  1992-06-02 DATE
# Raw headline:  World Trade News: Multinationals' cross-border trade surges
# NER Headline:  World Trade News ORG
# Date:  1992-06-02 DATE
# Raw headline:  China returns to 'Great Game' in Central Asia: Beijing's greatest fear is a rising tide of economic and ethnic turmoil in the emerging states
# NER Headline:  China GPE
# NER Headline:  'Great Game' WORK_OF_ART
# NER Headline:  Central Asia LOC
# NER Headline:  Beijing GPE
# Date:  1992-06-02 DATE
# Raw headline:  Business in Thailand urges new elections
# NER Headline:  Thailand GPE
# Date:  1992-06-02 DATE
# Raw headline:  Korean banks impose curbs on Hyundai
# NER Headline:  Korean NORP
# NER Headline:  Hyundai ORG
# Date:  1992-06-02 DATE
# Raw headline:  De Klerk visit to Russia puts end to decades of antipathy
# NER Headline:  De Klerk PERSON
# NER Headline:  Russia GPE
# Date:  1992-06-02 DATE
# Raw headline:  Key US index signals growth acceleration
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  Political fog descends on the last primary rites: The uncertainties that lie beyond inevitable wins for George Bush and Bill Clinton
# NER Headline:  George Bush PERSON
# NER Headline:  Bill Clinton PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Dinkins makes a strong sales pitch for the Big Apple
# NER Headline:  Dinkins PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Mexico retires over Dollars 7bn debt
# NER Headline:  Mexico GPE
# NER Headline:  Dollars 7bn FAC
# Date:  1992-06-02 DATE
# Raw headline:  Canada's unity talks resuming
# NER Headline:  Canada GPE
# Date:  1992-06-02 DATE
# Raw headline:  Colombia gives asylum to Peru's ex-president
# NER Headline:  Colombia GPE
# NER Headline:  Peru GPE
# Date:  1992-06-02 DATE
# Raw headline:  Rockwell fined Dollars 18.5m in nuclear waste disposal case
# NER Headline:  Rockwell ORG
# NER Headline:  Dollars 18.5 FAC
# Date:  1992-06-02 DATE
# Raw headline:  Hopes rise for declining rate of inflation
# Date:  1992-06-02 DATE
# Raw headline:  Eurofighter heads for German crash-landing
# NER Headline:  German NORP
# Date:  1992-06-02 DATE
# Raw headline:  Russian central bank chairman resigns: Matiukhin blames a running dispute with parliament over interest rates
# NER Headline:  Russian NORP
# Date:  1992-06-02 DATE
# Raw headline:  Moscow sets terms for defence of borders
# NER Headline:  Moscow GPE
# Date:  1992-06-02 DATE
# Raw headline:  Slovak populist shakes the federalist foundation: Word 'independence' is avoided, but rhetoric is unambiguous
# NER Headline:  Slovak GPE
# Date:  1992-06-02 DATE
# Raw headline:  Beregovoy survives vote by a whisker
# NER Headline:  Beregovoy PERSON
# Date:  1992-06-02 DATE
# Raw headline:  EC hits at US Earth Summit stance
# NER Headline:  EC ORG
# NER Headline:  US Earth Summit ORG
# Date:  1992-06-02 DATE
# Raw headline:  Investigators unravel Maxwell web: Liechtenstein companies are beyond the reach of creditors and pensioners
# NER Headline:  Maxwell ORG
# Date:  1992-06-02 DATE
# Raw headline:  R-R and Westinghouse forge power generation alliance
# NER Headline:  Westinghouse ORG
# Date:  1992-06-02 DATE
# Raw headline:  World News In Brief: Last chance for jail
# NER Headline:  World News In Brief ORG
# Date:  1992-06-02 DATE
# Raw headline:  World News In Brief: Soccer boss accused
# NER Headline:  World News In Brief ORG
# Date:  1992-06-02 DATE
# Raw headline:  Stock & Currency Markets
# NER Headline:  Stock & Currency Markets ORG
# Date:  1992-06-02 DATE
# Raw headline:  Hanson and P&O would make Canary Wharf offers under Pounds 600m
# NER Headline:  Hanson ORG
# NER Headline:  P&O ORG
# NER Headline:  Canary Wharf PERSON
# NER Headline:  Pounds 600 LAW
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (16): Technology alone is not enough - An issue underlying the labyrinthine discussions at Rio is technology transfer
# NER Headline:  The Earth Summit ORG
# NER Headline:  16): Technology PERCENT
# NER Headline:  Rio ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (17): Scientist with impeccable green credentials
# NER Headline:  The Earth Summit ORG
# NER Headline:  17 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (12): Man with a global mission - Profile of Maurice Strong
# NER Headline:  The Earth Summit ORG
# NER Headline:  12 DATE
# NER Headline:  Maurice Strong PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (15): The start of a process - Summit is 'a unique opportunity,' says Michael Howard
# NER Headline:  The Earth Summit ORG
# NER Headline:  15 DATE
# NER Headline:  Michael Howard PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (14): Cause for concern - Disappointment among environmental pressure groups
# NER Headline:  The Earth Summit ORG
# NER Headline:  14 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (13): Big companies are keen to look green - The business community is anxious about the  threat of 'green taxation' and over-regulation
# NER Headline:  The Earth Summit ORG
# NER Headline:  13 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (9): Difference of perspective - Third World countries are increasingly reluctant to take advice from industrialised nations
# NER Headline:  The Earth Summit ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (11): Business warms to plans for balanced development - Industry viewpoint
# NER Headline:  The Earth Summit ORG
# NER Headline:  11 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (10): Conflicting viewpoints - Industrialised Nations
# NER Headline:  The Earth Summit ORG
# NER Headline:  10 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (8): Population surge is a crucial issue - There may well be 10bn people on the earth by the year 2050
# NER Headline:  The Earth Summit ORG
# NER Headline:  8) CARDINAL
# NER Headline:  10bn ORDINAL
# NER Headline:  the year DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (7): Trade bans unlikely to succeed - Co-operation is better than coercion in persuading developing countries to adopt environmentally-friendly policies
# NER Headline:  The Earth Summit ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (5): A billion people in need - Fresh water supplies
# NER Headline:  The Earth Summit ORG
# NER Headline:  5 DATE
# NER Headline:  billion CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (6): Concern for earth's living wealth - Loss of species is wiping out a medicine chest of potential cures to serious disease
# NER Headline:  The Earth Summit ORG
# NER Headline:  6 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (3): A puzzle of fiendish complexity - Pollution of the atmospher
# NER Headline:  The Earth Summit ORG
# NER Headline:  3 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (4): Dismay over the lack of agreement - Land and rain forest protection
# NER Headline:  The Earth Summit ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (2): Rio is not just one event - but several - The Summit Agenda
# NER Headline:  The Earth Summit ORG
# NER Headline:  2): DATE
# NER Headline:  one CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  Survey of The Earth Summit (1): Vast agenda but thin on action - Few events have captured the world's imagination like the Earth Summit in Rio de Janeiro. But few have also given rise to as many misunderstandings and false hopes
# NER Headline:  The Earth Summit ORG
# NER Headline:  1 CARDINAL
# NER Headline:  the Earth Summit ORG
# NER Headline:  Rio de Janeiro GPE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (8): Competitive sector - The aerospace industry
# NER Headline:  Quebec GPE
# NER Headline:  8) CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (7): Recession, failures curb enthusiasm - Financial Services
# NER Headline:  Quebec GPE
# NER Headline:  Financial Services ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (9): Institution wields a big stick - Profile of Caisse de depot et placement du Quebec
# NER Headline:  Quebec GPE
# NER Headline:  9 DATE
# NER Headline:  Quebec GPE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (5): The power utility is fighting back - Profile of Hydro-Quebec
# NER Headline:  Quebec GPE
# NER Headline:  5 DATE
# NER Headline:  Hydro-Quebec ORG
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (6): A strong sense of survival - Montreal
# NER Headline:  Quebec GPE
# NER Headline:  6 DATE
# NER Headline:  Montreal GPE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (3): Positive business culture is a silver lining - The Economy
# NER Headline:  Quebec GPE
# NER Headline:  3 DATE
# NER Headline:  The Economy WORK_OF_ART
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (4): Cornerstone of economic development in the 1990s - Pharmaceuticals thrives in Montreal
# NER Headline:  Quebec GPE
# NER Headline:  4 DATE
# NER Headline:  1990s DATE
# NER Headline:  Montreal GPE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (2): Clusters hold key to markets - Industry
# NER Headline:  Quebec GPE
# NER Headline:  2 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Survey of Investment in Quebec (1): Political heat grows - In business, politics and culture, Canada's francophone province has become one of North America's most vibrant regions
# NER Headline:  Quebec GPE
# NER Headline:  1 CARDINAL
# NER Headline:  Canada GPE
# NER Headline:  North America's LOC
# Date:  1992-06-02 DATE
# Raw headline:  London Stock Exchange: Equity futures and options trading
# NER Headline:  London Stock Exchange ORG
# Date:  1992-06-02 DATE
# Raw headline:  London Stock Exchange: Heavy activity in Racal
# NER Headline:  London Stock Exchange ORG
# NER Headline:  Racal LOC
# Date:  1992-06-02 DATE
# Raw headline:  London Stock Exchange: Equities give ground as account opens
# NER Headline:  London Stock Exchange ORG
# Date:  1992-06-02 DATE
# Raw headline:  World Stock Markets (Asia Pacific): Nikkei average loses 1.9 per cent on arbitrage selling
# NER Headline:  World Stock Markets ORG
# NER Headline:  Asia Pacific LOC
# NER Headline:  1.9 per cent MONEY
# Date:  1992-06-02 DATE
# Raw headline:  World Stock Markets: South Africa
# NER Headline:  World Stock Markets ORG
# NER Headline:  South Africa GPE
# Date:  1992-06-02 DATE
# Raw headline:  World Stock Markets: Referendum poll switch lifts Copenhagen
# NER Headline:  World Stock Markets ORG
# NER Headline:  Copenhagen ORG
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: Weather worries spark surge in US grain prices
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  World Commodities Prices: Tea
# Date:  1992-06-02 DATE
# Raw headline:  Commodities and Agriculture: EC fishing off Canada suspended
# NER Headline:  EC ORG
# NER Headline:  Canada GPE
# Date:  1992-06-02 DATE
# Raw headline:  International Bonds: Enthusiastic response to French utility FFr3bn issue
# NER Headline:  French NORP
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: Hong Kong groups lift their eyes across the border - Developers are making the most of pro-China fervour by building land banks
# NER Headline:  International Capital Markets ORG
# NER Headline:  Hong Kong GPE
# NER Headline:  China GPE
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: ABN Amro in Hoare Govett deal
# NER Headline:  International Capital Markets ORG
# NER Headline:  ABN Amro ORG
# NER Headline:  Hoare Govett PERSON
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: UBS calls in Mountleigh bond after payment missed
# NER Headline:  International Capital Markets ORG
# NER Headline:  UBS ORG
# NER Headline:  Mountleigh ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Capital Markets: New risk chief at Chicago bank
# NER Headline:  International Capital Markets ORG
# NER Headline:  Chicago GPE
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: CSR in the red after ADollars 558m write-down
# NER Headline:  International Company News ORG
# NER Headline:  CSR ORG
# NER Headline:  558 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Outboard Marine and Volvo in venture
# NER Headline:  International Company News ORG
# NER Headline:  Outboard Marine PERSON
# NER Headline:  Volvo ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Lawson Mardon 9% ahead in first quarter
# NER Headline:  International Company News ORG
# NER Headline:  Lawson Mardon PERSON
# NER Headline:  9% PERCENT
# NER Headline:  first quarter DATE
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Upjohn places freeze on wages, hirings
# NER Headline:  International Company News ORG
# NER Headline:  Upjohn ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Corona first-quarter earnings depressed
# NER Headline:  International Company News ORG
# NER Headline:  Corona GPE
# NER Headline:  first-quarter DATE
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Rivals buy Steinberg food chain for CDollars 275m
# NER Headline:  International Company News: ORG
# NER Headline:  Steinberg PERSON
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Fujitsu to swallow rest of Poqet
# NER Headline:  International Company News ORG
# NER Headline:  Fujitsu ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Digital to lose 3,700 employees
# NER Headline:  International Company News ORG
# NER Headline:  Digital ORG
# NER Headline:  3,700 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Air France, Lufthansa shy from hotel merger
# NER Headline:  International Company News ORG
# NER Headline:  Air France ORG
# NER Headline:  Lufthansa ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: DG Bank to restructure overseas operations
# NER Headline:  International Company News ORG
# NER Headline:  DG Bank ORG
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Swiss business opens its doors to the world
# NER Headline:  International Company News ORG
# NER Headline:  Swiss NORP
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Carlsberg annual results expected to be unchanged
# NER Headline:  International Company News ORG
# NER Headline:  Carlsberg GPE
# NER Headline:  annual DATE
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Viag sees increase in profits and acquisitions
# NER Headline:  International Company News ORG
# NER Headline:  Viag PERSON
# Date:  1992-06-02 DATE
# Raw headline:  International Company News: Hoesch approves Krupp deal
# NER Headline:  International Company News ORG
# NER Headline:  Hoesch ORG
# NER Headline:  Krupp PERSON
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: BEP falls to Pounds 4m and board changes planned
# NER Headline:  UK Company News ORG
# NER Headline:  BEP ORG
# NER Headline:  Pounds 4 LAW
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: EIS expands via Pounds 10.7m purchase
# NER Headline:  UK Company News ORG
# NER Headline:  Pounds 10.7 WORK_OF_ART
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Deeper losses and refinancing at Porth
# NER Headline:  UK Company News ORG
# NER Headline:  Porth GPE
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Local advertising lifts Midlands Radio
# NER Headline:  UK Company News: Local ORG
# NER Headline:  Midlands Radio PERSON
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Record Pounds 2m at Hicking Pentecost
# NER Headline:  UK Company News ORG
# NER Headline:  Hicking Pentecost FAC
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: US financier claims to have taken stake in Dollars 1bn WPP debt
# NER Headline:  UK Company News ORG
# NER Headline:  US GPE
# NER Headline:  Dollars 1bn WPP ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Cullen's dips to Pounds 608,000
# NER Headline:  UK Company News: ORG
# NER Headline:  608,000 CARDINAL
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: MTM secures extended bank facilities
# NER Headline:  UK Company News ORG
# NER Headline:  MTM ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Disposals help Faber Prest advance to Pounds 1.84m
# NER Headline:  UK Company News: ORG
# NER Headline:  Faber Prest ORG
# NER Headline:  Pounds 1.84 FAC
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Westland advances 11% and seeks closer links with Agusta
# NER Headline:  UK Company News ORG
# NER Headline:  Westland GPE
# NER Headline:  11% PERCENT
# NER Headline:  Agusta ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Net assets fall by 24% at TR Property
# NER Headline:  UK Company News ORG
# NER Headline:  24% PERCENT
# NER Headline:  TR Property ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Borthwicks' flavours decision justified
# NER Headline:  UK Company News ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Hawthorn Leslie makes loss of Pounds 13.5m
# NER Headline:  UK Company News ORG
# NER Headline:  Hawthorn Leslie PERSON
# NER Headline:  Pounds 13.5 FAC
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Scholl steps into herbs
# NER Headline:  UK Company News ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Hongkong Bank raises stake
# NER Headline:  UK Company News ORG
# NER Headline:  Hongkong Bank ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: New trust from Kleinwort stable
# NER Headline:  UK Company News ORG
# NER Headline:  Kleinwort ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Moratorium by Walbrook Ins
# NER Headline:  UK Company News ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Dowty shares dip below cash offer
# NER Headline:  UK Company News ORG
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Celestion Audio and Kef both sold to SE Asian Kinergetics
# NER Headline:  UK Company News ORG
# NER Headline:  Kef PERSON
# NER Headline:  Asian NORP
# Date:  1992-06-02 DATE
# Raw headline:  UK Company News: Pacific Horizon hits out at manager Jupiter Tyndall
# NER Headline:  UK Company News ORG
# NER Headline:  Pacific Horizon ORG
# NER Headline:  Jupiter Tyndall PERSON
# Date:  1992-06-02 DATE
# Raw headline:  A new red flag flies over eastern Europe: Coca-Cola is pouring resources into the former communist countries in a battle for market share
# NER Headline:  Europe LOC
# NER Headline:  Coca-Cola ORG
# Date:  1992-06-02 DATE
# Raw headline:  Anglo American rises 15% and sees economic upturn
# NER Headline:  Anglo American NORP
# NER Headline:  15% PERCENT
# Date:  1992-06-02 DATE
# Raw headline:  The Lex Column: Sears
# NER Headline:  Sears ORG
# Date:  1992-06-02 DATE
# Raw headline:  The Lex Column: US economy
# NER Headline:  US GPE
# Date:  1992-06-02 DATE
# Raw headline:  The Lex Column: Electricity
# Date:  1992-06-02 DATE
# Raw headline:  The Lex Column: Westland
# Date:  1992-06-02 DATE
# Raw headline:  The Lex Column: The accountants' audit
# Date:  1992-06-02 DATE
# Raw headline:  BBC on-air promotion excessive, says MMC
# NER Headline:  BBC ORG
# NER Headline:  MMC ORG
# Date:  1992-06-02 DATE
# Raw headline:  Japan to complain to EC over review of relations
# NER Headline:  Japan GPE
# NER Headline:  EC ORG
# Date:  1992-06-02 DATE
# Raw headline:  Letter: Realistic small company audit
# Date:  1992-06-02 DATE
# Raw headline:  Letter: Rationale for European Central Bank in London
# NER Headline:  European Central Bank ORG
# NER Headline:  London GPE
# Date:  1992-06-02 DATE
# Raw headline:  The essence of leadership
# Date:  1992-06-02 DATE
# Raw headline:  Arts: Today's Television
# NER Headline:  Today DATE
# Date:  1992-06-02 DATE
# Raw headline:  Arts: Biko - Opera
# NER Headline:  Biko - Opera ORG
# Date:  1992-06-02 DATE
# Raw headline:  Arts: Musicians who miss the Wigmore - Music in London
# NER Headline:  the Wigmore - Music ORG
# NER Headline:  London GPE
# Date:  1992-06-02 DATE
# Raw headline:  People: Gearing up for the stock market
# Date:  1992-06-02 DATE
# Raw headline:  People: Financial moves
# Date:  1992-06-02 DATE
# Raw headline:  Business Law: Cadbury Committee draft offers mixed news for stakeholders
# NER Headline:  Cadbury Committee ORG
# Date:  1992-06-02 DATE
# Raw headline:  People: Dashing up
# Date:  1992-06-02 DATE
# Raw headline:  Technology: Globetrotters at spaghetti junction - Technically Speaking
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): Stitching up designers to use computers - In a nutshell
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): Playing safe with the bank manager - In a nutshell
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): New venture for Foreign & Colonial - In a nutshell
# NER Headline:  Foreign & Colonial - In ORG
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): Government help is an important factor - In a nutshell
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): All change for the VAT regime - In a nutshell
# NER Headline:  VAT ORG
# Date:  1992-06-02 DATE
# Raw headline:  Management (The Growing Business): What's in a name? - Choosing the right title for your company is no simple matter although it can make all the difference between commercial success or failure
# Date:  1992-06-02 DATE
# Raw headline:  Minister challenges private sector
# Date:  1992-06-02 DATE
# Raw headline:  International league of awards led by Britain
# NER Headline:  Britain GPE
# Date:  1992-06-02 DATE
# Raw headline:  Ulster talks try to solve row
# NER Headline:  Ulster PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Aid plan for Names considered
# NER Headline:  Names ORG
# Date:  1992-06-02 DATE
# Raw headline:  Moi blames west for low growth
# NER Headline:  Moi PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Manila to speed poll count
# NER Headline:  Manila GPE
# Date:  1992-06-02 DATE
# Raw headline:  Aid pledges grow for southern Africa
# NER Headline:  Africa LOC
# Date:  1992-06-02 DATE
# Raw headline:  Japan to lend Dollars 300m to Brazil
# NER Headline:  Japan GPE
# NER Headline:  Dollars 300 CARDINAL
# NER Headline:  Brazil GPE
# Date:  1992-06-02 DATE
# Raw headline:  Iraq condemns UN border proposals
# NER Headline:  Iraq GPE
# NER Headline:  UN ORG
# Date:  1992-06-02 DATE
# Raw headline:  Brain surgery for Arafat
# NER Headline:  Arafat PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Bankruptcies in Japan double in 1991
# NER Headline:  Japan GPE
# NER Headline:  1991 DATE
# Date:  1992-06-02 DATE
# Raw headline:  Germany breaks link of pollutants and growth
# NER Headline:  Germany GPE
# Date:  1992-06-02 DATE
# Raw headline:  Canadians to tackle impasse in unity talks
# NER Headline:  Canadians NORP
# Date:  1992-06-02 DATE
# Raw headline:  Amnesty critical of Peru regime
# NER Headline:  Amnesty ORG
# NER Headline:  Peru GPE
# Date:  1992-06-02 DATE
# Raw headline:  Business as usual at Anglo-Yugoslavia
# NER Headline:  Anglo NORP
# Date:  1992-06-02 DATE
# Raw headline:  UK bank spells out new rules
# NER Headline:  UK GPE
# Date:  1992-06-02 DATE
# Raw headline:  Master Slovak politician shakes the federalist foundation: The word 'independence' may be avoided, but the rhetoric is unambiguous
# NER Headline:  Slovak PERSON
# Date:  1992-06-02 DATE
# Raw headline:  Chaos obscures casualties of Serbian sanctions: Energy-dependent industry and tobacco exports are likely to be quickly affected
# NER Headline:  Serbian NORP
# Date:  1992-06-02 DATE
# Raw headline:  Eurofighter heads for German crash-landing
# NER Headline:  German NORP
# Date:  1992-06-02 DATE
# Raw headline:  World News in Brief: Bomb defused
# NER Headline:  World News ORG
# Date:  1992-06-02 DATE
# Raw headline:  World News in Brief: 'Years of misery' for senior policewoman
# NER Headline:  World News ORG
# NER Headline:  Years DATE
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Hundreds left stranded at Belgrade airport
# NER Headline:  UN Sanctions Against Serbia ORG
# NER Headline:  Hundreds CARDINAL
# NER Headline:  Belgrade GPE
# Date:  1992-06-01 DATE
# Raw headline:  World News in Brief: Lucky strike
# NER Headline:  World News ORG
# Date:  1992-06-01 DATE
# Raw headline:  World News in Brief: Poll deaths
# NER Headline:  World News ORG
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (11): Key Facts
# NER Headline:  Spain GPE
# NER Headline:  11 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Justinian: A trespasser in the skies
# Date:  1992-06-01 DATE
# Raw headline:  International Bonds: Top Danish bank launches Dollars 100m subordinated FRNs
# NER Headline:  Danish NORP
# NER Headline:  100 CARDINAL
# Date:  1992-06-01 DATE
# Raw headline:  International Capital Markets: Being beastly to the bankers
# NER Headline:  International Capital Markets ORG
# Date:  1992-06-01 DATE
# Raw headline:  US Money and Credit: Economic data point to modest growth
# NER Headline:  US Money and Credit: Economic ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Ferruzzi down sharply as debt expenses climb
# NER Headline:  International Company News ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Finmeccanica float closer
# NER Headline:  International Company News ORG
# NER Headline:  Finmeccanica GPE
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Qantas merger considered
# NER Headline:  International Company News ORG
# NER Headline:  Qantas ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Integro in Dutch expansion
# NER Headline:  International Company News ORG
# NER Headline:  Dutch NORP
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Coca-Cola to invest Dollars 1bn in E Europe
# NER Headline:  International Company News ORG
# NER Headline:  Coca-Cola ORG
# NER Headline:  1bn ORDINAL
# NER Headline:  E Europe LOC
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Cross Border M&A Deals
# NER Headline:  International Company News ORG
# NER Headline:  Cross Border M&A Deals ORG
# Date:  1992-06-01 DATE
# Raw headline:  RBC may lose up to CDollars 300m on O&Y loans
# NER Headline:  RBC ORG
# NER Headline:  up to CARDINAL
# NER Headline:  O&Y ORG
# Date:  1992-06-01 DATE
# Raw headline:  Chambers of trade and commerce set to agree on merger
# Date:  1992-06-01 DATE
# Raw headline:  Ten arrests at unveiling of 'Bomber' Harris statue
# NER Headline:  Ten CARDINAL
# NER Headline:  Harris PERSON
# Date:  1992-06-01 DATE
# Raw headline:  Binding the moral and political wounds: Italy's new president will seek urgent action
# NER Headline:  Italy GPE
# Date:  1992-06-01 DATE
# Raw headline:  Observer: New blues
# Date:  1992-06-01 DATE
# Raw headline:  Observer: Old cronies
# Date:  1992-06-01 DATE
# Raw headline:  Observer: Price puzzle
# Date:  1992-06-01 DATE
# Raw headline:  Observer: Durlacher's turn
# Date:  1992-06-01 DATE
# Raw headline:  Observer: For whom the poll tells
# Date:  1992-06-01 DATE
# Raw headline:  Leading Article: Paying up for Maxwell victims
# NER Headline:  Maxwell ORG
# Date:  1992-06-01 DATE
# Raw headline:  Leading Article: The road to Rio
# NER Headline:  Rio ORG
# Date:  1992-06-01 DATE
# Raw headline:  Countries don't go broke
# Date:  1992-06-01 DATE
# Raw headline:  Arts: Glittering history in Portman Square - Architecture
# NER Headline:  Portman Square - Architecture FAC
# Date:  1992-06-01 DATE
# Raw headline:  Arts: Russia comes to Israel - Theatre
# NER Headline:  Russia GPE
# NER Headline:  Israel - Theatre ORG
# Date:  1992-06-01 DATE
# Raw headline:  Arts: Appliance of science - Sponsorship
# Date:  1992-06-01 DATE
# Raw headline:  Arts: Today's Television
# NER Headline:  Today DATE
# Date:  1992-06-01 DATE
# Raw headline:  Management: Toil and trouble
# Date:  1992-06-01 DATE
# Raw headline:  Management: The great top-down fallacy
# Date:  1992-06-01 DATE
# Raw headline:  Management: Secret confessions of a secretary
# Date:  1992-06-01 DATE
# Raw headline:  Many shopworkers face freeze on pay
# Date:  1992-06-01 DATE
# Raw headline:  Reform call for textiles industry
# Date:  1992-06-01 DATE
# Raw headline:  Union backs plan to merge
# Date:  1992-06-01 DATE
# Raw headline:  Tribunal ruling
# NER Headline:  Tribunal ORG
# Date:  1992-06-01 DATE
# Raw headline:  Strike vote over pay
# Date:  1992-06-01 DATE
# Raw headline:  Sexual harassment 'frequent'
# Date:  1992-06-01 DATE
# Raw headline:  Barry ready to harry supporters of Militant: The man who today becomes leader of Britain's biggest Civil Service union
# NER Headline:  Barry PERSON
# NER Headline:  harry PERSON
# NER Headline:  today DATE
# NER Headline:  Britain GPE
# NER Headline:  Civil Service ORG
# Date:  1992-06-01 DATE
# Raw headline:  Gadaffi's guns elude police dragnets
# NER Headline:  Gadaffi PERSON
# Date:  1992-06-01 DATE
# Raw headline:  Talks on Ulster to reopen today
# NER Headline:  Ulster PERSON
# NER Headline:  today DATE
# Date:  1992-06-01 DATE
# Raw headline:  Gould backs party link with unions
# Date:  1992-06-01 DATE
# Raw headline:  Investment boost seen in the west Midlands
# Date:  1992-06-01 DATE
# Raw headline:  MP hopeful on BCCI disclosures
# NER Headline:  BCCI ORG
# Date:  1992-06-01 DATE
# Raw headline:  CBI calls for law against 'squatting'
# NER Headline:  CBI ORG
# Date:  1992-06-01 DATE
# Raw headline:  Housing market hopes boosted
# Date:  1992-06-01 DATE
# Raw headline:  University decides to stick to the federation trail: The row over department mergers at Manchester
# Date:  1992-06-01 DATE
# Raw headline:  Riverbus survives storm at Canary Wharf
# NER Headline:  Riverbus ORG
# NER Headline:  Canary Wharf FAC
# Date:  1992-06-01 DATE
# Raw headline:  Closure threat to two north-east coal mines
# NER Headline:  two CARDINAL
# NER Headline:  north-east GPE
# Date:  1992-06-01 DATE
# Raw headline:  Charity funds for Tories attacked
# NER Headline:  Tories NORP
# Date:  1992-06-01 DATE
# Raw headline:  Pre-tax petrol price 'low in real terms'
# Date:  1992-06-01 DATE
# Raw headline:  Attitudes harden in Gaza: Conditions worsening in the occupied territories
# NER Headline:  Gaza GPE
# Date:  1992-06-01 DATE
# Raw headline:  Economic forecasts can endanger your wealth
# Date:  1992-06-01 DATE
# Raw headline:  Green shoots of good intention from business: The boardroom view of the Earth Summit
# NER Headline:  the Earth Summit LOC
# Date:  1992-06-01 DATE
# Raw headline:  Rabuka poised to regain control
# NER Headline:  Rabuka PERSON
# Date:  1992-06-01 DATE
# Raw headline:  CBS plans to charge affiliates
# NER Headline:  CBS ORG
# Date:  1992-06-01 DATE
# Raw headline:  Indonesia opposition in show of strength
# NER Headline:  Indonesia GPE
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Belgrade protesters express their shame
# NER Headline:  UN Sanctions Against Serbia ORG
# NER Headline:  Belgrade GPE
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Moves to end trade and freeze assets
# NER Headline:  UN Sanctions Against Serbia: Moves ORG
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Penalties 'a devastating blow to Serbian economy'
# NER Headline:  UN Sanctions Against Serbia ORG
# NER Headline:  Serbian NORP
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Milosevic in a fight to save his political life - Serbian militia forces would see any appeal by the president to bring an end to the fighting as a betrayal of their cause
# NER Headline:  UN Sanctions Against Serbia ORG
# NER Headline:  Milosevic PERSON
# NER Headline:  Serbian NORP
# Date:  1992-06-01 DATE
# Raw headline:  UN Sanctions Against Serbia: Sport ban 'will make average guy think'
# NER Headline:  UN Sanctions Against Serbia ORG
# Date:  1992-06-01 DATE
# Raw headline:  France's smoking habit given a kick
# NER Headline:  France GPE
# Date:  1992-06-01 DATE
# Raw headline:  Denmark sees surge in Maastricht support
# NER Headline:  Denmark ORG
# NER Headline:  Maastricht GPE
# Date:  1992-06-01 DATE
# Raw headline:  Ceasefire in Sarajevo as sanctions take effect: Demonstrators against war in Bosnia march through Serbian capital
# NER Headline:  Sarajevo GPE
# NER Headline:  Bosnia GPE
# NER Headline:  Serbian NORP
# Date:  1992-06-01 DATE
# Raw headline:  Canary Wharf job moves mooted before collapse
# NER Headline:  Canary Wharf PERSON
# Date:  1992-06-01 DATE
# Raw headline:  Wealthy nations balk at costs of conservation treaty
# Date:  1992-06-01 DATE
# Raw headline:  World News In Brief: Top slot
# NER Headline:  World News In Brief ORG
# Date:  1992-06-01 DATE
# Raw headline:  World News In Brief: Mansell pipped
# NER Headline:  World News In Brief ORG
# NER Headline:  Mansell PERSON
# Date:  1992-06-01 DATE
# Raw headline:  World News In Brief: CSR
# NER Headline:  World News In Brief ORG
# NER Headline:  CSR ORG
# Date:  1992-06-01 DATE
# Raw headline:  World News In Brief: Car window death
# NER Headline:  World News In Brief ORG
# Date:  1992-06-01 DATE
# Raw headline:  World News In Brief: Suspected ETA chief held
# NER Headline:  World News In Brief ORG
# NER Headline:  ETA ORG
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (10): A national diet of movies and soccer - Private tv takes on the public networks
# NER Headline:  Spain GPE
# NER Headline:  10 CARDINAL
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (9): Ascent to Europe gets tougher - Economy
# NER Headline:  Spain GPE
# NER Headline:  9): Ascent ORG
# NER Headline:  Europe LOC
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (7): Homage to Catalonia - Barcelona awaits the Games
# NER Headline:  Spain GPE
# NER Headline:  Catalonia GPE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (8): Start at El Aeropuerto - A no-nonsense A-Z guide for the businessperson in Spain
# NER Headline:  Spain GPE
# NER Headline:  8) CARDINAL
# NER Headline:  El Aeropuerto FAC
# NER Headline:  Spain GPE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (6): The strain in Spain - Pressures for greater regional autonomy are growing stronger
# NER Headline:  Spain GPE
# NER Headline:  6 DATE
# NER Headline:  Spain GPE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (5): The hesitant tendency - Trade unions drift uneasily into a showdown with Madrid
# NER Headline:  Spain GPE
# NER Headline:  5 DATE
# NER Headline:  Madrid GPE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (4): The people's friend - An interview with Alvaro Gil-Robles, the Spanish ombudsman
# NER Headline:  Spain GPE
# NER Headline:  4 DATE
# NER Headline:  Alvaro Gil-Robles PERSON
# NER Headline:  Spanish NORP
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (3): Heirs not so apparent are waiting in the wings - Some of the leaders who could one day win the top job
# NER Headline:  Spain GPE
# NER Headline:  3 DATE
# NER Headline:  Heirs ORG
# NER Headline:  one day DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (2): Ten years, and still running - Prime Minister Felipe Gonzalez resets his sights
# NER Headline:  Spain GPE
# NER Headline:  2): DATE
# NER Headline:  Ten years DATE
# NER Headline:  Felipe Gonzalez PERSON
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Spain (1): Comes the reckoning - Spain is celebrating its political and economic rebirth in flamboyant style. When the year's festivities are over, it will be asked to start paying the high price of its return to democracy and its European Community status
# NER Headline:  Spain GPE
# NER Headline:  Spain GPE
# NER Headline:  year DATE
# NER Headline:  European Community ORG
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (5): Further expansion possible for Glaxo - Profile
# NER Headline:  Singapore GPE
# NER Headline:  5 DATE
# NER Headline:  Glaxo - Profile ORG
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (8): Performance slumps - Financial Services
# NER Headline:  8) CARDINAL
# NER Headline:  Financial Services ORG
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (9): Mixed trends and fortunes - Hotels and Property
# NER Headline:  Singapore GPE
# NER Headline:  9 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (7): A softer approach - Politics
# NER Headline:  Singapore GPE
# NER Headline:  7 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (6): Challenges for the prime minister
# NER Headline:  Singapore GPE
# NER Headline:  6 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (2): Breaking a high-energy diet is not easy - The Economy
# NER Headline:  2 DATE
# NER Headline:  The Economy WORK_OF_ART
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (4): Political maturity needed - Foreign Affairs
# NER Headline:  Singapore GPE
# NER Headline:  4 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (3): A computer-driven future - Information Technology
# NER Headline:  Singapore GPE
# NER Headline:  3 DATE
# Date:  1992-06-01 DATE
# Raw headline:  Survey of Singapore (1): Victim of its own success - Singapore has become not only a regional economic power but also a country poised to jump into the very top league of industrialised countries. But behind the image of achievement and efficiency there are problems
# NER Headline:  1): Victim DATE
# NER Headline:  Singapore GPE
# Date:  1992-06-01 DATE
# Raw headline:  The new politics of dependency
# Date:  1992-06-01 DATE
# Raw headline:  Monday Interview: Exhibitor of good connections - Richard Breeden, chairman of the US Securities and Exchange Commission
# NER Headline:  Monday DATE
# NER Headline:  Richard Breeden PERSON
# NER Headline:  the US Securities and Exchange Commission ORG
# Date:  1992-06-01 DATE
# Raw headline:  Foreign Exchanges and Money Markets: Testing times for Dollars
# Date:  1992-06-01 DATE
# Raw headline:  International Bonds: Floating-rate sector stirs after dormant two years
# NER Headline:  two years DATE
# Date:  1992-06-01 DATE
# Raw headline:  UK Gilts: Success of future funding in doubt
# NER Headline:  UK GPE
# Date:  1992-06-01 DATE
# Raw headline:  European Bonds: Focus on Danish treaty referendum
# NER Headline:  European NORP
# NER Headline:  Danish NORP
# Date:  1992-06-01 DATE
# Raw headline:  Japanese Bonds: Concern mounts over trade surplus
# NER Headline:  Japanese NORP
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: SA investors extend Dutch broker interest
# NER Headline:  International Company News ORG
# NER Headline:  Dutch NORP
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: US faces up to the realities of oversupply - O&Y's woes have spoiled dreams of property sector recovery
# NER Headline:  International Company News ORG
# NER Headline:  US GPE
# NER Headline:  O&Y ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Weak demand hits steelmakers
# NER Headline:  International Company News ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: SEC to ease rules for asset-backed offerings
# NER Headline:  International Company News ORG
# NER Headline:  SEC ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Correction - European Parliament
# NER Headline:  International Company News ORG
# NER Headline:  Correction - European Parliament ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Ferruzzi down sharply as debt expenses climb
# NER Headline:  International Company News ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Greece Fund board to amend structure
# NER Headline:  International Company News ORG
# NER Headline:  Greece Fund ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Arco's 17.5% Wytch Farm stake up for sale
# NER Headline:  International Company News ORG
# NER Headline:  Arco ORG
# NER Headline:  17.5% PERCENT
# NER Headline:  Wytch Farm ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Banesto, BP may resolve stake dispute
# NER Headline:  International Company News ORG
# NER Headline:  Banesto ORG
# NER Headline:  BP ORG
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Japanese credit banks report mixed results
# NER Headline:  International Company News ORG
# NER Headline:  Japanese NORP
# Date:  1992-06-01 DATE
# Raw headline:  International Company News: Mirror Group appoints Rowe & Pitman as lead broker
# ...
# Raw headline:  Prospect of collapse keeps Sorrell on top: The man at WPP's helm inspires mixed feelings
# NER Headline:  WPP ORG
# Date:  1992-05-29 DATE
# Raw headline:  MEPC warns of downturn at full year: UK property company reinforces gloom with fall of 13% over six months
# NER Headline:  full year DATE
# NER Headline:  UK GPE
# NER Headline:  13% PERCENT
# NER Headline:  six months DATE
# Date:  1992-05-29 DATE
# Raw headline:  Profits continue to fall at Japanese banks: Bad loans and higher costs take toll at year-end
# NER Headline:  Japanese NORP
# NER Headline:  year-end DATE
# Date:  1992-05-29 DATE
# Raw headline:  The Lex Column: Storehouse
# Date:  1992-05-29 DATE
# Raw headline:  The Lex Column: Water sector
# Date:  1992-05-29 DATE
# Raw headline:  The Lex Column: Thorn EMI
# Date:  1992-05-29 DATE
# Raw headline:  The Lex Column: MEPC
# Date:  1992-05-29 DATE
# Raw headline:  The Lex Column: Ripples from Docklands
# NER Headline:  Docklands GPE
# Date:  1992-05-29 DATE
# Raw headline:  Russian managers reluctant to adopt western practices
# NER Headline:  Russian NORP
# Date:  1992-05-29 DATE
# Raw headline:  Bond faces jail after dishonesty conviction
# Date:  1992-05-29 DATE
# Raw headline:  Observer: Down the river
# Date:  1992-05-29 DATE
# Raw headline:  Observer: L of a reason
# Date:  1992-05-29 DATE
# Raw headline:  Observer: On the move
# Date:  1992-05-29 DATE
# Raw headline:  Observer: Still kicking
# Date:  1992-05-29 DATE
# Raw headline:  Observer: Those who teach . . .
# Date:  1992-05-29 DATE
# Raw headline:  Letter: Views of balance of payments trend in UK too relaxed
# NER Headline:  UK GPE
# Date:  1992-05-29 DATE
# Raw headline:  Letter: Insights into investment performance of pensions
# Date:  1992-05-29 DATE
# Raw headline:  France accelerates into the overtaking lane
# NER Headline:  France GPE
# Date:  1992-05-29 DATE
# Raw headline:  Letter: Reality of pound
# Date:  1992-05-29 DATE
# Raw headline:  Ghosts of the decade past: The Japanese banking system is under strain from doubtful property loans and a sliding stock market
# NER Headline:  the decade DATE
# NER Headline:  Japanese NORP
# Date:  1992-05-29 DATE
# Raw headline:  Freedom's radio days are not yet over
# Date:  1992-05-29 DATE
# Raw headline:  Leading Article: Swiss movement
# Date:  1992-05-29 DATE
# Raw headline:  Leading Article: Damp strike
# Date:  1992-05-29 DATE
# Raw headline:  Arts: Berlin Festival Fringe
# Date:  1992-05-29 DATE
# Raw headline:  Arts: Today's Television
# NER Headline:  Today DATE
# Date:  1992-05-29 DATE
# Raw headline:  Arts: Venus Observed
# NER Headline:  Venus Observed PERSON
# Date:  1992-05-29 DATE
# Raw headline:  Technology (Worth Watching): Sea sponge soaks up barnacles
# Date:  1992-05-29 DATE
# Raw headline:  Technology (Worth Watching): Good vibrations on the local network
# Date:  1992-05-29 DATE
# Raw headline:  Technology (Worth Watching): Two cables are better than one
# NER Headline:  Two CARDINAL
# Date:  1992-05-29 DATE
# Raw headline:  Technology (Worth Watching): Driven to distraction
# Date:  1992-05-29 DATE
# Raw headline:  Technology: Optical illusion on disc
# Date:  1992-05-29 DATE
# Raw headline:  Technology: Feel the force - Apple will today unveil Newton, an electronic gadget which it claims will help you take control of your life
# NER Headline:  Apple ORG
# NER Headline:  today DATE
# NER Headline:  Newton ORG
# Date:  1992-05-29 DATE
# Raw headline:  Management: Making the boss feel above par
# Date:  1992-05-29 DATE
# Raw headline:  Management: No credit to banks - Why the clearers seem unable to match other companies in terms of service
# Date:  1992-05-29 DATE
# Raw headline:  Law Report: Digest of Easter Term cases
# Date:  1992-05-29 DATE
# Raw headline:  People: P&O expands into Asian waters
# NER Headline:  Asian NORP
# Date:  1992-05-29 DATE
# Raw headline:  Canary Wharf: What now for Docklands? - A body blow to plans for east London
# NER Headline:  Canary Wharf PERSON
# NER Headline:  Docklands GPE
# NER Headline:  London GPE
# Date:  1992-05-29 DATE
# Raw headline:  Air freight value up sharply
# Date:  1992-05-29 DATE
# Raw headline:  Payouts increase in race bias cases
# Date:  1992-05-29 DATE
# Raw headline:  Chicago brokerage charged
# NER Headline:  Chicago GPE
# Date:  1992-05-29 DATE
# Raw headline:  Perot seeks clutch of expert advisers
# Date:  1992-05-29 DATE
# Raw headline:  Rights to the planet's many species in dispute
# Date:  1992-05-29 DATE
# Raw headline:  House passes energy bill with oil-saving aim
# NER Headline:  House ORG
# Date:  1992-05-29 DATE
# Raw headline:  Hurd boosts Mexican links
# NER Headline:  Hurd PERSON
# NER Headline:  Mexican NORP
# Date:  1992-05-29 DATE
# Raw headline:  An embarrassment of riches for President Suharto: The opposition, set to lose the coming election, is making accusations of nepotism
# NER Headline:  Suharto PERSON
# Date:  1992-05-29 DATE
# Raw headline:  Growth in South Korea shows quarterly slowdown
# NER Headline:  South Korea GPE
# NER Headline:  quarterly DATE
# Date:  1992-05-29 DATE
# Raw headline:  HK looks forward to monetary authority
# Date:  1992-05-29 DATE
# Raw headline:  Defiant Bond loses licence to indulge in overkill
# Date:  1992-05-29 DATE
# Raw headline:  Mandela sets out moderate path for ANC
# NER Headline:  Mandela PERSON
# NER Headline:  ANC ORG
# Date:  1992-05-29 DATE
# Raw headline:  World Trade News: Greek exporters take to the sea, air and narrow road - War in what was Yugoslavia, means finding new routes to European Community markets
# NER Headline:  World Trade News ORG
# NER Headline:  Greek NORP
# NER Headline:  Yugoslavia GPE
# NER Headline:  European Community ORG
# Date:  1992-05-29 DATE
# Raw headline:  World Trade News: Japan warns US chip makers over imports pressure
# NER Headline:  World Trade News ORG
# NER Headline:  Japan GPE
# NER Headline:  US GPE
# Date:  1992-05-29 DATE
# Raw headline:  World Trade News: Third world 'faces neglect from industrial nations'
# NER Headline:  World Trade News ORG
# NER Headline:  Third ORDINAL
# Date:  1992-05-29 DATE
# Raw headline:  World Trade News: Pepsico in Belarus bottle joint venture
# NER Headline:  World Trade News ORG
# NER Headline:  Belarus GPE
# Date:  1992-05-29 DATE
# Raw headline:  Government gives boost to home-grown capitalism
# Date:  1992-05-29 DATE
# Raw headline:  Italy's new president calls for reform
# NER Headline:  Italy GPE
# Date:  1992-05-29 DATE
# Raw headline:  Russian role in Moldova underlined
# NER Headline:  Russian NORP
# NER Headline:  Moldova GPE
# Date:  1992-05-29 DATE
# Raw headline:  Danes wonder if it's time to get off the Eurowagon: Many voters are having second thoughts about EC unity
# NER Headline:  Danes NORP
# NER Headline:  Eurowagon PRODUCT
# NER Headline:  second ORDINAL
# NER Headline:  EC ORG
# Date:  1992-05-29 DATE
# Raw headline:  Mars loses a round in battle over ice-cream
# NER Headline:  Mars LOC
# Date:  1992-05-29 DATE
# Raw headline:  Poland to turn to secret past
# NER Headline:  Poland GPE
# Date:  1992-05-29 DATE
# Raw headline:  Italian interim leader: Correction
# NER Headline:  Italian NORP
# Date:  1992-05-29 DATE
# Raw headline:  Shanghai shock for bulls in China's stock market shops
# NER Headline:  Shanghai GPE
# NER Headline:  China GPE
# Date:  1992-05-29 DATE
# Raw headline:  World News in Brief: Paracetamol review
# NER Headline:  World News ORG
# Date:  1992-05-29 DATE
# Raw headline:  UN chief says no to troop relief for Bosnia
# NER Headline:  UN ORG
# NER Headline:  Bosnia GPE
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (10): Poland sets the pattern - Eastern Europe's move towards convertible currencies
# NER Headline:  10 DATE
# NER Headline:  Poland GPE
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (12): Optimism about union dims - Europe has embarked on the arduous task of making Emu a reality
# NER Headline:  12 DATE
# NER Headline:  Europe LOC
# NER Headline:  Emu PERSON
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (11): Still only a distant dream
# NER Headline:  11 DATE
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (8): Drawing a line on currency
# NER Headline:  8) CARDINAL
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (6): The Square Mile stays out in front
# NER Headline:  6 DATE
# NER Headline:  The Square Mile WORK_OF_ART
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (7): Risk-taking is his business  -Profile of Julian Simmonds
# NER Headline:  Julian NORP
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (2): Well set to weather storms - Dollar
# NER Headline:  2 DATE
# Date:  1992-05-29 DATE
# Raw headline:  Survey of Foreign Exchange (3): Stability amid turmoil - Yen shrugs off changes in the Japanese economy
# NER Headline:  3 CARDINAL
# NER Headline:  Japanese NORP
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 25
#      23 full_date = "{}-{}-{}".format(year, month, day)
#      24 date_ner = NER(full_date).ents[0].label_
# ---> 25 headline_ner = NER(headline).ents
#      26 print("Date: ", full_date, date_ner)
#      27 print("Raw headline: ", headline)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/language.py:1049, in Language.__call__(self, text, disable, component_cfg)
#    1047     error_handler = proc.get_error_handler()
#    1048 try:
# -> 1049     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050 except KeyError as e:
#    1051     # This typically happens if a component is not initialized
#    1052     raise ValueError(Errors.E109.format(name=name)) from e
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/pipeline/transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/pipeline/transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/ml/tb_framework.py:34, in forward(model, X, is_train)
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#      37         unseen_classes=model.attrs["unseen_classes"],
#      38         train=is_train,
#      39         has_upper=model.attrs["has_upper"],
#      40     )
#      42     return step_model, step_model.finish_steps
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/ml/parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/with_array.py:36, in forward(model, Xseq, is_train)
#      32 def forward(
#      33     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      34 ) -> Tuple[SeqT, Callable]:
#      35     if isinstance(Xseq, Ragged):
# ---> 36         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      37     elif isinstance(Xseq, Padded):
#      38         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/with_array.py:91, in _ragged_forward(model, Xr, is_train)
#      87 def _ragged_forward(
#      88     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      89 ) -> Tuple[Ragged, Callable]:
#      90     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 91     Y, get_dX = layer(Xr.dataXd, is_train)
#      93     def backprop(dYr: Ragged) -> Ragged:
#      94         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# KeyboardInterrupt:
